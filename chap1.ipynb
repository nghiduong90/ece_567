# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
# searching text in concordance view which can shows every occurrence of a given in contexts
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text2.concordance("lived")
# Out:
# Displaying 20 of 20 matches:
# re , for many generations , they had lived in so respectable a manner as to eng
# f this estate was a single man , who lived to a very advanced age , and who for
# ght have found it impossible to have lived together so long , had not a particu
# ge and handsome ; and the Middletons lived in a style of equal hospitality and
# two daughters , both of whom she had lived to see respectably married , and she
# " " As good a kind of fellow as ever lived , I assure you . A very decent shot
# sort of fellow , I believe , as ever lived ," repeated Sir John . " I remember
#  I know very little , though we have lived together for years ; but of Willough
# six or seven hundred a year ; but he lived at an expense to which that income c
# She thought it probable that as they lived in the same county , Mrs . Palmer mi
# and happy had it been if she had not lived to overcome those regrets which the
# ...

# %%
text3.concordance("beautiful")
# Out:
# Displaying 1 of 1 matches:
# h was tender eyed ; but Rachel was beautiful and well favoured . And Jacob love

# %%
# find the similar words to "montrous" that can fit in contexts of text1
text1.similar("monstrous")
# Out:
# determined uncommon exasperate mean modifies mouldy doleful fearless
# mystifying abundant subtly perilous true lamentable domineering candid
# gamesome few christian part

# %%
text3.similar("beautiful")
# Out:
# hagar tamar barren babel so naked parted keturah fierce dry troubled
# afraid barr weaned hirah joktan dinhabah avith naamah light

# %%
text3.concordance("pretty")
# Out:
# No matches

# %%
text3.concordance("awesome")
# Out:
# No matches

# %%
text2.concordance("beautiful")
# Out:
# Displaying 12 of 12 matches:
# ardly keep my seat . To hear those beautiful lines which have frequently almost
# ole country about them abounded in beautiful walks . The high downs which invit
#  cant of praise , she was called a beautiful girl , truth was less violently ou
# grounds were declared to be highly beautiful , and Sir John , who was particula
#  - green , behind the house , to a beautiful hanging wood , and on the other yo
# deur , is our cottage ." " It is a beautiful country ," he replied ; " but thes
# o examine them . " Oh ! dear , how beautiful these are ! Well ! how delightful
# rd at Exeter that you are the most beautiful creatures in the world ; and I hav
# he was . " Norland is a prodigious beautiful place , is not it ?" added Miss St
#  whom they declared to be the most beautiful , elegant , accomplished , and agr
# the particulars , was so fine , so beautiful a Sunday as to draw many to Kensin
# ...

# %%
text2.concordance("pretty")
# Out:
# Displaying 25 of 36 matches:
# n . The Miss Dashwoods were young , pretty , and unaffected . It was enough to
# for to be unaffected was all that a pretty girl could want to make her mind as
# ous to get a good husband for every pretty girl . The immediate advantage to h
# tell you , Miss Dashwood ; he has a pretty little estate of his own in Somerse
# regular features , and a remarkably pretty figure . Marianne was still handsom
# r ONE morning I think you have done pretty well . You have already ascertained
# ure you .-- There is one remarkably pretty sitting room up stairs ; of a nice
# nly the Palmers . Charlotte is very pretty , I can tell you . You may see her
# he was short and plump , had a very pretty face , and the finest expression of
#  Palmer , you shall see a monstrous pretty girl ." He immediately went into th
#  house ; but they say it is a sweet pretty place ." " As vile a spot as I ever
# must be some other place that is so pretty I suppose ." When they were seated
# ...

# %%
text2.similar("pretty")
# Out:
# good little well considerable long happy disappointed as rich stout
# large unfortunate quiet much red handsome material beautiful soon
# differently

# %%
# use common_contexts to examine just the contexts that are shared by two or more words
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty is_pretty am_glad a_lucky be_glad

# %%
text2.common_contexts(["beautiful", "pretty"])
# Out:
# a_girl so_a

# %%
text2.common_contexts(["absolutely", "cetainly"])
# Out:
# ('The following word(s) were not found:', 'absolutely cetainly')

# %%
text1.common_contexts(["idea", "thought"])
# Out:
# the_of all_of

# %%
# use dispersion plot to see the location of words in a text (in a figure)
# %matplotlib inline
text1.dispersion_plot(["monstrous", "very", "beautiful"])

# %%
text3
# Out:
# <Text: The Book of Genesis>

# %%
text3.generate("brother")

# %%
len(text3)
# Out:
# 44764

# %%
len_set_text3 = sorted(set(text3))

# %%
len_set_text3
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
len(len_set_text3)
# Out:
# 2789

# %%
from __future__ import division
text3_richness = len(text3) / len(len_set_text3)
text3_richness
# Out:
# 16.050197203298673

# %% [markdown]
# def lexical_diversity(text):
#     """
#     Function to calculate text richness
#     """
#     return len(text) / len(set(text))
#
# def percentage(word, text):
#     """
#     function to calculate a word in a text
#     """
#     return 100 * text.count(word) / len(text)

# %%
def lexical_diversity(text): 
    """ 
    Function to calculate text richness 
    """ 
    return len(text) / len(set(text))

def percentage(word, text): 
    """ 
    function to calculate a word in a text 
    """ 
    return 100 * text.count(word) / len(text)

# %%
lexical_diversity(text3)
percentage("an", text3)
# Out:
# 0.1697792869269949

# %%
lexical_diversity(text3)
# Out:
# 16.050197203298673

# %%
percentage("an", text3)
# Out:
# 0.1697792869269949

# %%
# list 
sent1 = ['call', 'me', 'Ishmael', '.']
sent1
lexical_diversity(sent1)
# Out:
# 1.0

# %%
len(sent1)
# Out:
# 4

# %%
type(text1)
# Out:
# nltk.text.Text

# %%
text1[100]
# Out:
# 'and'

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1[0: 100]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '"',
# ...

# %%
text2[100:200]
# Out:
# ['and',
#  'housekeeper',
#  'in',
#  'his',
#  'sister',
#  '.',
#  'But',
#  'her',
#  'death',
#  ',',
#  'which',
#  'happened',
#  'ten',
#  'years',
#  'before',
#  'his',
#  'own',
#  ',',
#  'produced',
#  'a',
#  'great',
#  'alteration',
#  'in',
#  'his',
#  'home',
#  ';',
#  'for',
#  'to',
#  'supply',
#  'her',
#  'loss',
#  ',',
#  'he',
#  'invited',
#  'and',
#  'received',
#  'into',
#  'his',
#  'house',
#  'the',
#  'family',
#  'of',
#  'his',
#  'nephew',
#  'Mr',
#  '.',
#  'Henry',
#  'Dashwood',
#  ',',
#  'the',
#  'legal',
#  'inheritor',
#  'of',
#  'the',
#  'Norland',
#  'estate',
#  ',',
#  'and',
#  'the',
#  'person',
#  'to',
#  'whom',
#  'he',
#  'intended',
#  'to',
#  'bequeath',
#  'it',
#  '.',
#  'In',
#  'the',
#  'society',
#  'of',
#  'his',
#  'nephew',
#  'and',
#  'niece',
#  ',',
#  'and',
#  'their',
#  'children',
#  ',',
#  'the',
#  'old',
#  'Gentleman',
#  "'",
#  's',
#  'days',
#  'were',
#  'comfortably',
#  'spent',
#  '.',
# ...

# %%
len(text1)
# Out:
# 260819

# %%
sent = ['word1', 'word2', 'word3', 'word4', 'word5',
        'word6', 'word7', 'word8', 'word9', 'word10']
sent[0]
# Out:
# 'word1'

# %%
sent[9]
# Out:
# 'word10'

# %%
sent[10]
# Out:
# --------------------------------------------------------------
# IndexError                   Traceback (most recent call last)
# <ipython-input-48-baa8b4ccd19d> in <module>()
# ----> 1 sent[10]
#
# IndexError: list index out of range

# %%
sent[5:8]
# Out:
# ['word6', 'word7', 'word8']

# %%
sent[5]
# Out:
# 'word6'

# %%
sent[6]
# Out:
# 'word7'

# %%
text2[141525:]
# Out:
# ['among',
#  'the',
#  'merits',
#  'and',
#  'the',
#  'happiness',
#  'of',
#  'Elinor',
#  'and',
#  'Marianne',
#  ',',
#  'let',
#  'it',
#  'not',
#  'be',
#  'ranked',
#  'as',
#  'the',
#  'least',
#  'considerable',
#  ',',
#  'that',
#  'though',
#  'sisters',
#  ',',
#  'and',
#  'living',
#  'almost',
#  'within',
#  'sight',
#  'of',
#  'each',
#  'other',
#  ',',
#  'they',
#  'could',
#  'live',
#  'without',
#  'disagreement',
#  'between',
#  'themselves',
#  ',',
#  'or',
#  'producing',
#  'coolness',
#  'between',
#  'their',
#  'husbands',
#  '.',
#  'THE',
#  'END']

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']

# %%
my_sent = ['Bravely', 'bold', 'Sir', 'Robin', ',', 'rode', 'forth', 'from', 'Camelot', '.']

# %%
noun_phrase = my_sent[1:4]

# %%
noun_phrase
# Out:
# ['bold', 'Sir', 'Robin']

# %%
wOrDs = sorted(noun_phrase)

# %%
wOrDs
# Out:
# ['Robin', 'Sir', 'bold']

# %%
not = 'Camelot'
# Out:
#   File "<ipython-input-59-673e7f915d89>", line 1
#     not = 'Camelot'
#         ^
# SyntaxError: invalid syntax

# %%
vocab = set(text1)

# %%
vocab_size = len(vocab)

# %%
vocab_size
# Out:
# 19317

# %%
name = 'Monty'

# %%
name[0]
# Out:
# 'M'

# %%
name[:4]
# Out:
# 'Mont'

# %%
name * 2
# Out:
# 'MontyMonty'

# %%
name + '!'
# Out:
# 'Monty!'

# %%
' '.join(['Monty', 'Python'])
# Out:
# 'Monty Python'

# %%
'Monty Python'.split()
# Out:
# ['Monty', 'Python']

# %%
# Computing with Language: Simple Statistics
saying = ['After', 'all', 'is', 'said', 'and', 'done',
          'more', 'is', 'said', 'than', 'done']
tokens = set(saying)
tokens = sorted(tokens)
tokens[-2:]
# Out:
# ['said', 'than']

# %%
# Frequency Distributions
fdist1 = FreqDist(text1)
print(fdist1)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
fdist1['whale']
# Out:
# 906

# %%
# Fine-grained Selection of Words
V = set(text1)
long_words = [w for w in V if len(w) > 15]
sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
fdist5 = FreqDist(text5)
sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7)
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
# Collocations and Bigrams
list(bigrams(['more', 'is', 'said', 'than', 'done']))
[('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text8.collocations()
# Out:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build

# %%
# Counting Other Things
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
fdist = FreqDist(len(w) for w in text1)
print(fdist)
fdist
# Out:
# <FreqDist with 19 samples and 260819 outcomes>
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %%
fdist.most_common()
fdist.max()
fdist[3]
fdist.freq(3)
# Out:
# 0.19255882431878046

# %%
fdist.max()
# Out:
# 3

# %%
fdist[3]
# Out:
# 50223

# %%
# Making Decisions and Taking Control
sent7
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.']

# %%
[w for w in sent7 if len(w) < 4]
# Out:
# [',', '61', 'old', ',', 'the', 'as', 'a', '29', '.']

# %%
[w for w in sent7 if len(w) <= 4]
# Out:
# [',', '61', 'old', ',', 'will', 'join', 'the', 'as', 'a', 'Nov.', '29', '.']

# %%
[w for w in sent7 if len(w) == 4]
# Out:
# ['will', 'join', 'Nov.']

# %%
[w for w in sent7 if len(w) != 4]
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  '29',
#  '.']

# %%
sorted(w for w in set(text1) if w.endswith('ableness'))
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted(term for term in set(text4) if 'gnt' in term)
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted(item for item in set(text6) if item.istitle())
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %%
sorted(item for item in set(sent7) if item.isdigit())
# Out:
# ['29', '61']

# %%
sorted(w for w in set(text7) if '-' in w and 'index' in w)
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %%
sorted(wd for wd in set(text3) if wd.istitle() and len(wd) > 10)
# Out:
# ['Abelmizraim',
#  'Allonbachuth',
#  'Beerlahairoi',
#  'Canaanitish',
#  'Chedorlaomer',
#  'Girgashites',
#  'Hazarmaveth',
#  'Hazezontamar',
#  'Ishmeelites',
#  'Jegarsahadutha',
#  'Jehovahjireh',
#  'Kirjatharba',
#  'Melchizedek',
#  'Mesopotamia',
#  'Peradventure',
#  'Philistines',
#  'Zaphnathpaaneah']

# %%
sorted(w for w in set(sent7) if not w.islower())
# Out:
# [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']

# %%
sorted(t for t in set(text2) if 'cie' in t or 'cei' in t)
# Out:
# ['ancient',
#  'ceiling',
#  'conceit',
#  'conceited',
#  'conceive',
#  'conscience',
#  'conscientious',
#  'conscientiously',
#  'deceitful',
#  'deceive',
#  'deceived',
#  'deceiving',
#  'deficiencies',
#  'deficiency',
#  'deficient',
#  'delicacies',
#  'excellencies',
#  'fancied',
#  'insufficiency',
#  'insufficient',
#  'legacies',
#  'perceive',
#  'perceived',
#  'perceiving',
#  'prescience',
#  'prophecies',
#  'receipt',
#  'receive',
#  'received',
#  'receiving',
#  'society',
#  'species',
#  'sufficient',
#  'sufficiently',
#  'undeceive',
#  'undeceiving']

# %%
# Operating on Every Element
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
[w.upper() for w in text1]
# Out:
# ['[',
#  'MOBY',
#  'DICK',
#  'BY',
#  'HERMAN',
#  'MELVILLE',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'SUPPLIED',
#  'BY',
#  'A',
#  'LATE',
#  'CONSUMPTIVE',
#  'USHER',
#  'TO',
#  'A',
#  'GRAMMAR',
#  'SCHOOL',
#  ')',
#  'THE',
#  'PALE',
#  'USHER',
#  '--',
#  'THREADBARE',
#  'IN',
#  'COAT',
#  ',',
#  'HEART',
#  ',',
#  'BODY',
#  ',',
#  'AND',
#  'BRAIN',
#  ';',
#  'I',
#  'SEE',
#  'HIM',
#  'NOW',
#  '.',
#  'HE',
#  'WAS',
#  'EVER',
#  'DUSTING',
#  'HIS',
#  'OLD',
#  'LEXICONS',
#  'AND',
#  'GRAMMARS',
#  ',',
#  'WITH',
#  'A',
#  'QUEER',
#  'HANDKERCHIEF',
#  ',',
#  'MOCKINGLY',
#  'EMBELLISHED',
#  'WITH',
#  'ALL',
#  'THE',
#  'GAY',
#  'FLAGS',
#  'OF',
#  'ALL',
#  'THE',
#  'KNOWN',
#  'NATIONS',
#  'OF',
#  'THE',
#  'WORLD',
#  '.',
#  'HE',
#  'LOVED',
#  'TO',
#  'DUST',
#  'HIS',
#  'OLD',
#  'GRAMMARS',
#  ';',
#  'IT',
#  'SOMEHOW',
#  'MILDLY',
#  'REMINDED',
#  'HIM',
#  'OF',
#  'HIS',
#  'MORTALITY',
#  '.',
#  '"',
# ...

# %%
len(text1)
# Out:
# 260819

# %%
len(set(text1))
# Out:
# 19317

# %%
len(set(word.lower() for word in text1))
# Out:
# 17231

# %%
len(set(word.lower() for word in text1 if word.isalpha()))
# Out:
# 16948

# %%
word = 'cat'
if len(word) < 5:
    print('word length is less than 5')
# Out:
# word length is less than 5

# %%
if len(word) >= 5:
  print('word length is greater than or equal to 5')

# %%
for word in ['Call', 'me', 'Ishmael', '.']:
    print(word)
# Out:
# Call
# me
# Ishmael
# .

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']
for xyzzy in sent1:
    if xyzzy.endswith('l'):
        print(xyzzy)
# Out:
# Call
# Ishmael

# %%
for token in sent1:
    if token.islower():
        print(token, 'is a lowercase word')
    elif token.istitle():
        print(token, 'is a titlecase word')
    else:
        print(token, 'is punctuation')
# Out:
# Call is a titlecase word
# me is a lowercase word
# Ishmael is a titlecase word
# . is punctuation

# %%
tricky = sorted(w for w in set(text2) if 'cie' in w or 'cei' in w)
for word in tricky:
    print(word, end=' ')
# Out:
# ancient ceiling conceit conceited conceive conscience conscientious conscientiously deceitful deceive deceived deceiving deficiencies deficiency deficient delicacies excellencies fancied insufficiency insufficient legacies perceive perceived perceiving prescience prophecies receipt receive received receiving society species sufficient sufficiently undeceive undeceiving
